# %%
# python libraries
import numpy as np 
import matplotlib.pyplot as plt 
import collections
import hashlib
import numbers
import matplotlib.cm as cm
from sys import getsizeof
from datetime import datetime
from pathlib import Path
import os

from IPython.display import HTML
import re

# tensorflow and its dependencies 
import tensorflow as tf
from tensorflow.python.eager import context
from tensorflow.python.framework import constant_op
from tensorflow.python.framework import dtypes
from tensorflow.python.framework import ops

from tensorflow.python.framework import tensor_shape
from tensorflow.python.framework import tensor_util
from tensorflow.python.layers import base as base_layer
from tensorflow.python.ops import array_ops
from tensorflow.python.ops import clip_ops
from tensorflow.python.ops import init_ops
from tensorflow.python.ops import math_ops
from tensorflow.python.ops import nn_ops
from tensorflow.python.ops import partitioned_variables
from tensorflow.python.ops import random_ops
from tensorflow.python.ops import tensor_array_ops
from tensorflow.python.ops import variable_scope as vs
from tensorflow.python.ops import variables as tf_variables
from tensorflow.python.platform import tf_logging as logging
from tensorflow.python.util import nest
from tensorflow.contrib.rnn.python.ops.core_rnn_cell import _Linear
from tensorflow.contrib import slim

## user defined modules 
# kernel rnn cell 
import kernl_rnn_cell
import adding_problem

# %%
BATCH_SIZE=50
TIME_STEPS=100

# %%
inputs , targets =adding_problem.get_batch(BATCH_SIZE,TIME_STEPS)

# %%
# Training Parameters
weight_learning_rate = 1e-6
tensor_learning_rate = 1e-8 # learning rate for sensitivity tensor and temporal filter tensor 
training_steps = 5000
batch_size = 20
display_step = 20
grad_clip=100
# Network Parameters
num_input = 2 # adding problem data input (first input are the random digits , second input is the mask)
time_steps = 100
num_hidden = 100 # hidden layer num of features
num_output = 1 # value of the addition estimation 
# 



# Noise Parameters
perturbation_std=1e-4
log_dir = os.environ['HOME']+"/MyData/KeRNL/logs/bptt_rnn_addition/add_eta_tensor_%1.0e_eta_weight_%1.0e_batch_%1.0e_hum_hidd_%1.0e_gc_%1.0e_steps_%1.0e_run_%s" %(tensor_learning_rate,weight_learning_rate,batch_size,num_hidden,grad_clip,training_steps, datetime.now().strftime("%Y%m%d_%H%M"))
log_dir
# Out:
# '/home/eghbal/MyData/KeRNL/logs/kernl_rnn_addition/add_eta_tensor_1e-08_eta_weight_1e-06_batch_2e+01_hum_hidd_1e+02_gc_1e+02_steps_5e+03_run_20190224_1657'

# %%
## define KeRNL unit
def bptt_rnn(x,rnn_weights,rnn_bias):
    # Define a KeRNL cell, the initialization is done inside the cell with default initializers
    with tf.variable_scope("bptt",initializer=tf.initializers.identity()) as scope: 
        rnn_cell = tf.contrib.rnn.BasicRNNCell(num_hidden,name='irnn')
        rnn_outputs, rnn_states = tf.nn.dynamic_rnn(rnn_cell, x, dtype=tf.float32)
        rnn_output=tf.matmul(rnn_outputs[:,-1,:], rnn_weights) +rnn_biases
     
    return rnn_output, rnn_states

# %%
tf.reset_default_graph()
graph=tf.Graph()
with graph.as_default():
    with tf.variable_scope('bptt_output',initializer=tf.initializers.random_normal()) as scope:
        rnn_weights = tf.get_variable(shape=[num_hidden, num_output],name='output_weight')
        rnn_biases = tf.get_variable(shape=[num_output],name='output_addition')
    # define weights and inputs to the network
    X = tf.placeholder("float", [None, time_steps, num_input])
    Y = tf.placeholder("float", [None, num_output])
    # define a function for extraction of variable names
    rnn_output,rnn_states=bptt_rnn(X,rnn_weights,rnn_biases)
    trainables=tf.trainable_variables()
    variable_names=[v.name for v in tf.trainable_variables()]
    #
    find_joing_index = lambda x, name_1,name_2 : [a and b for a,b in zip([np.unicode_.find(k.name, name_1)>-1 for k in x] ,[np.unicode_.find(k.name, name_2)>-1 for k in x])].index(True)
    # find trainable parameters for kernl
    with tf.name_scope("bptt_Trainables") as scope:
            # find trainables parameters for bptt
        bptt_output_weight_index= find_joing_index(trainables,'bptt','output_weight')
        bptt_output_addition_index= find_joing_index(trainables,'bptt','output_addition')
        bptt_kernel_index= find_joing_index(trainables,'bptt','kernel')
        bptt_bias_index= find_joing_index(trainables,'bptt','bias')
            #
        bptt_weight_training_indices=np.asarray([bptt_kernel_index,bptt_bias_index,bptt_output_weight_index,bptt_output_addition_index],dtype=np.int)
        bptt_weight_trainables= [trainables[k] for k in bptt_weight_training_indices]
            
            ##################
            ## bptt train ####
            ##################
    with tf.name_scope("bptt_train") as scope:
                # BPTT
        bptt_loss_output_prediction=tf.losses.mean_squared_error(Y,rnn_output)
                # define optimizer
        bptt_weight_optimizer = tf.train.RMSPropOptimizer(learning_rate=weight_learning_rate)
        bptt_grads=tf.gradients(bptt_loss_output_prediction,bptt_weight_trainables)
        bptt_weight_grads_and_vars=list(zip(bptt_grads,bptt_weight_trainables))
                # Apply gradient Clipping to recurrent weights
        bptt_cropped_weight_grads_and_vars=[(tf.clip_by_norm(grad, grad_clip),var) if  np.unicode_.find(var.name,'output')==-1 else (grad,var) for grad,var in bptt_weight_grads_and_vars]
                # apply gradients
        bptt_weight_train_op = bptt_weight_optimizer.apply_gradients(bptt_cropped_weight_grads_and_vars)
                
                
                ##################
                # SUMMARIES ######
                ##################
                
    with tf.name_scope("bptt_summaries") as scope:
                    # bptt kernel
        tf.summary.histogram('bptt_kernel_grad',bptt_grads[0]+1e-10)
        tf.summary.histogram('bptt_kernel', bptt_weight_trainables[0]+1e-10)
                    # bptt output weight
        tf.summary.histogram('bptt_output_weight_grad',bptt_grads[2]+1e-10)
        tf.summary.histogram('bptt_output_weights', bptt_weight_trainables[2]+1e-10)
                    # bptt output bias
        tf.summary.histogram('bptt_output_addition_grad',bptt_grads[3]+1e-10)
        tf.summary.histogram('bptt_output_addition', bptt_weight_trainables[3]+1e-10)
                    # bptt loss and accuracy
        tf.summary.scalar('bptt_loss_output_prediction',bptt_loss_output_prediction+1e-10)
                    # bptt kernel and ouput matrix
            #tf.summary.image('bptt_kernel_matrix',tf.expand_dims(tf.expand_dims(bptt_weight_trainables[0],axis=0),axis=-1))
            #tf.summary.image('bptt_kernel_grad',tf.expand_dims(tf.expand_dims(bptt_grads[0],axis=0),axis=-1))
            #tf.summary.image('bptt_output_matrix',tf.expand_dims(tf.expand_dims(bptt_weight_trainables[2],axis=0),axis=-1))
            #tf.summary.image('bptt_output_matrix_grad',tf.expand_dims(tf.expand_dims(bptt_grads[2],axis=0),axis=-1))
        bptt_merged_summary_op=tf.summary.merge_all(scope="bptt_summaries")
                    
                    
        init = tf.global_variables_initializer()
        saver = tf.train.Saver()
# Out:
# WARNING:tensorflow:From <ipython-input-5-a422bd198a13>:5: BasicRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.SimpleRNNCell, and will be replaced by that in Tensorflow 2.0.

# %%
# verify initialization
config = tf.ConfigProto()
config.gpu_options.allow_growth = True

with tf.Session(graph=graph,) as sess : 
    sess.run(init)
    values,trainable_vars = sess.run([variable_names,trainables])
    for k, v in zip(variable_names,values):
        print(["variable: " , k])
        #print(["value: " , v])
        print(["variable: " , np.unicode_.find(k,'output')]) 
        print(["shape: " , v.shape])
        #print(v) training_steps
# Out:
# ['variable: ', 'bptt_output/output_weight:0']
# ['variable: ', 5]
# ['shape: ', (100, 1)]
# ['variable: ', 'bptt_output/output_addition:0']
# ['variable: ', 5]
# ['shape: ', (1,)]
# ['variable: ', 'bptt/rnn/irnn/kernel:0']
# ['variable: ', -1]
# ['shape: ', (102, 100)]
# ['variable: ', 'bptt/rnn/irnn/bias:0']
# ['variable: ', -1]
# ['shape: ', (100,)]

# %%
Path(log_dir).mkdir(exist_ok=True, parents=True)
filelist = [ f for f in os.listdir(log_dir) if f.endswith(".local") ]
for f in filelist:
    os.remove(os.path.join(log_dir, f))

# %%
# write graph into tensorboard 
tb_writer = tf.summary.FileWriter(log_dir,graph)
# run a training session 
with tf.Session(graph=graph) as sess:
    sess.run(init)
    for step in range(1,training_steps+1):
        batch_x, batch_y = adding_problem.get_batch(batch_size=batch_size,time_steps=time_steps)
        # bptt train 
        bptt_train, bptt_loss,bptt_merged_summary=sess.run([bptt_weight_train_op,bptt_loss_output_prediction,bptt_merged_summary_op],feed_dict={X:batch_x, Y:batch_y})
        
        # run summaries 
        #bptt_merged_summary=sess.run(bptt_merged_summary_op,feed_dict={X:batch_x, Y:batch_y})
       
        tb_writer.add_summary(bptt_merged_summary, global_step=step)

        # 
        if step % display_step==0 or step==1 : 
            # get batch loss and accuracy 
            print('Step: {},bptt train Loss: {:.3f}'.format(step + 1, bptt_loss))


    print("Optimization Finished!")
    #test_data = mnist.test.images[:test_len].reshape((-1, timesteps, num_input))
    #test_label = mnist.test.labels[:test_len]
    #print("Testing Accuracy:", 
    #    sess.run(loss_output_prediction, feed_dict={X: test_data, Y: test_label}))
    save_path = saver.save(sess, log_dir+"/model.ckpt", global_step=step,write_meta_graph=True)
    print("Model saved in path: %s" % save_path)
# Out:
# Step: 2,bptt train Loss: 0.774
# Step: 21,bptt train Loss: 1.158
# Step: 41,bptt train Loss: 0.520
# Step: 61,bptt train Loss: 0.670
# Step: 81,bptt train Loss: 0.558
# Step: 101,bptt train Loss: 0.516
# Step: 121,bptt train Loss: 0.474
# Step: 141,bptt train Loss: 0.538
# Step: 161,bptt train Loss: 0.967
# Step: 181,bptt train Loss: 0.446
# Step: 201,bptt train Loss: 0.417
# Step: 221,bptt train Loss: 0.382
# Step: 241,bptt train Loss: 0.382
# Step: 261,bptt train Loss: 0.265
# Step: 281,bptt train Loss: 0.496
# Step: 301,bptt train Loss: 0.361
# Step: 321,bptt train Loss: 0.552
# Step: 341,bptt train Loss: 0.442
# Step: 361,bptt train Loss: 0.382
# Step: 381,bptt train Loss: 0.315
# Step: 401,bptt train Loss: 0.468
# Step: 421,bptt train Loss: 0.730
# Step: 441,bptt train Loss: 0.630
# Step: 461,bptt train Loss: 0.668
# Step: 481,bptt train Loss: 0.317
# Step: 501,bptt train Loss: 0.186
# Step: 521,bptt train Loss: 0.308
# Step: 541,bptt train Loss: 0.631
# Step: 561,bptt train Loss: 0.324
# Step: 581,bptt train Loss: 0.432
# Step: 601,bptt train Loss: 0.192
# Step: 621,bptt train Loss: 0.416
# Step: 641,bptt train Loss: 0.501
# Step: 661,bptt train Loss: 0.401
# Step: 681,bptt train Loss: 0.280
# Step: 701,bptt train Loss: 0.364
# Step: 721,bptt train Loss: 0.226
# Step: 741,bptt train Loss: 0.307
# Step: 761,bptt train Loss: 0.251
# Step: 781,bptt train Loss: 0.330
# Step: 801,bptt train Loss: 0.307
# Step: 821,bptt train Loss: 0.356
# Step: 841,bptt train Loss: 0.617
# Step: 861,bptt train Loss: 0.407
# Step: 881,bptt train Loss: 0.161
# Step: 901,bptt train Loss: 0.222
# Step: 921,bptt train Loss: 0.443
# Step: 941,bptt train Loss: 0.299
# Step: 961,bptt train Loss: 0.396
# Step: 981,bptt train Loss: 0.119
# Step: 1001,bptt train Loss: 0.283
# Step: 1021,bptt train Loss: 0.277
# Step: 1041,bptt train Loss: 0.429
# Step: 1061,bptt train Loss: 0.281
# Step: 1081,bptt train Loss: 0.261
# Step: 1101,bptt train Loss: 0.505
# Step: 1121,bptt train Loss: 0.269
# Step: 1141,bptt train Loss: 0.537
# Step: 1161,bptt train Loss: 0.529
# Step: 1181,bptt train Loss: 0.267
# Step: 1201,bptt train Loss: 0.198
# Step: 1221,bptt train Loss: 0.345
# Step: 1241,bptt train Loss: 0.362
# Step: 1261,bptt train Loss: 0.337
# Step: 1281,bptt train Loss: 0.524
# Step: 1301,bptt train Loss: 0.271
# Step: 1321,bptt train Loss: 0.319
# Step: 1341,bptt train Loss: 0.212
# Step: 1361,bptt train Loss: 0.216
# Step: 1381,bptt train Loss: 0.265
# Step: 1401,bptt train Loss: 0.139
# Step: 1421,bptt train Loss: 0.311
# Step: 1441,bptt train Loss: 0.462
# Step: 1461,bptt train Loss: 0.350
# Step: 1481,bptt train Loss: 0.234
# Step: 1501,bptt train Loss: 0.120
# Step: 1521,bptt train Loss: 0.239
# Step: 1541,bptt train Loss: 0.359
# Step: 1561,bptt train Loss: 0.272
# Step: 1581,bptt train Loss: 0.476
# Step: 1601,bptt train Loss: 0.362
# Step: 1621,bptt train Loss: 0.230
# Step: 1641,bptt train Loss: 0.384
# Step: 1661,bptt train Loss: 0.360
# Step: 1681,bptt train Loss: 0.298
# Step: 1701,bptt train Loss: 0.223
# Step: 1721,bptt train Loss: 0.251
# Step: 1741,bptt train Loss: 0.273
# Step: 1761,bptt train Loss: 0.196
# Step: 1781,bptt train Loss: 0.239
# Step: 1801,bptt train Loss: 0.430
# Step: 1821,bptt train Loss: 0.225
# Step: 1841,bptt train Loss: 0.265
# Step: 1861,bptt train Loss: 0.416
# Step: 1881,bptt train Loss: 0.251
# Step: 1901,bptt train Loss: 0.233
# Step: 1921,bptt train Loss: 0.191
# Step: 1941,bptt train Loss: 0.259
# Step: 1961,bptt train Loss: 0.344
# Step: 1981,bptt train Loss: 0.322
# Step: 2001,bptt train Loss: 0.226
# Step: 2021,bptt train Loss: 0.310
# Step: 2041,bptt train Loss: 0.400
# Step: 2061,bptt train Loss: 0.208
# Step: 2081,bptt train Loss: 0.274
# Step: 2101,bptt train Loss: 0.368
# Step: 2121,bptt train Loss: 0.485
# Step: 2141,bptt train Loss: 0.396
# Step: 2161,bptt train Loss: 0.252
# Step: 2181,bptt train Loss: 0.313
# Step: 2201,bptt train Loss: 0.225
# Step: 2221,bptt train Loss: 0.216
# Step: 2241,bptt train Loss: 0.372
# Step: 2261,bptt train Loss: 0.173
# Step: 2281,bptt train Loss: 0.216
# Step: 2301,bptt train Loss: 0.225
# Step: 2321,bptt train Loss: 0.283
# Step: 2341,bptt train Loss: 0.356
# Step: 2361,bptt train Loss: 0.233
# Step: 2381,bptt train Loss: 0.307
# Step: 2401,bptt train Loss: 0.366
# Step: 2421,bptt train Loss: 0.202
# Step: 2441,bptt train Loss: 0.268
# Step: 2461,bptt train Loss: 0.212
# Step: 2481,bptt train Loss: 0.151
# Step: 2501,bptt train Loss: 0.415
# Step: 2521,bptt train Loss: 0.210
# Step: 2541,bptt train Loss: 0.291
# Step: 2561,bptt train Loss: 0.261
# Step: 2581,bptt train Loss: 0.135
# Step: 2601,bptt train Loss: 0.426
# Step: 2621,bptt train Loss: 0.215
# Step: 2641,bptt train Loss: 0.265
# Step: 2661,bptt train Loss: 0.392
# Step: 2681,bptt train Loss: 0.347
# Step: 2701,bptt train Loss: 0.197
# Step: 2721,bptt train Loss: 0.168
# Step: 2741,bptt train Loss: 0.173
# Step: 2761,bptt train Loss: 0.368
# Step: 2781,bptt train Loss: 0.212
# Step: 2801,bptt train Loss: 0.227
# Step: 2821,bptt train Loss: 0.184
# Step: 2841,bptt train Loss: 0.179
# Step: 2861,bptt train Loss: 0.383
# Step: 2881,bptt train Loss: 0.386
# Step: 2901,bptt train Loss: 0.240
# Step: 2921,bptt train Loss: 0.210
# Step: 2941,bptt train Loss: 0.186
# Step: 2961,bptt train Loss: 0.271
# Step: 2981,bptt train Loss: 0.361
# Step: 3001,bptt train Loss: 0.153
# Step: 3021,bptt train Loss: 0.265
# Step: 3041,bptt train Loss: 0.126
# Step: 3061,bptt train Loss: 0.164
# Step: 3081,bptt train Loss: 0.151
# Step: 3101,bptt train Loss: 0.266
# Step: 3121,bptt train Loss: 0.161
# Step: 3141,bptt train Loss: 0.295
# Step: 3161,bptt train Loss: 0.342
# Step: 3181,bptt train Loss: 0.164
# Step: 3201,bptt train Loss: 0.185
# Step: 3221,bptt train Loss: 0.389
# Step: 3241,bptt train Loss: 0.241
# Step: 3261,bptt train Loss: 0.403
# Step: 3281,bptt train Loss: 0.291
# Step: 3301,bptt train Loss: 0.309
# Step: 3321,bptt train Loss: 0.207
# Step: 3341,bptt train Loss: 0.156
# Step: 3361,bptt train Loss: 0.323
# Step: 3381,bptt train Loss: 0.326
# Step: 3401,bptt train Loss: 0.215
# Step: 3421,bptt train Loss: 0.225
# Step: 3441,bptt train Loss: 0.394
# Step: 3461,bptt train Loss: 0.324
# Step: 3481,bptt train Loss: 0.235
# Step: 3501,bptt train Loss: 0.174
# Step: 3521,bptt train Loss: 0.316
# Step: 3541,bptt train Loss: 0.145
# Step: 3561,bptt train Loss: 0.228
# Step: 3581,bptt train Loss: 0.184
# Step: 3601,bptt train Loss: 0.206
# Step: 3621,bptt train Loss: 0.106
# Step: 3641,bptt train Loss: 0.248
# Step: 3661,bptt train Loss: 0.177
# Step: 3681,bptt train Loss: 0.107
# Step: 3701,bptt train Loss: 0.170
# Step: 3721,bptt train Loss: 0.173
# Step: 3741,bptt train Loss: 0.286
# Step: 3761,bptt train Loss: 0.190
# Step: 3781,bptt train Loss: 0.254
# Step: 3801,bptt train Loss: 0.238
# Step: 3821,bptt train Loss: 0.212
# Step: 3841,bptt train Loss: 0.207
# Step: 3861,bptt train Loss: 0.376
# Step: 3881,bptt train Loss: 0.251
# Step: 3901,bptt train Loss: 0.208
# Step: 3921,bptt train Loss: 0.476
# Step: 3941,bptt train Loss: 0.252
# Step: 3961,bptt train Loss: 0.283
# Step: 3981,bptt train Loss: 0.322
# Step: 4001,bptt train Loss: 0.132
# Step: 4021,bptt train Loss: 0.362
# Step: 4041,bptt train Loss: 0.157
# Step: 4061,bptt train Loss: 0.256
# Step: 4081,bptt train Loss: 0.278
# Step: 4101,bptt train Loss: 0.187
# Step: 4121,bptt train Loss: 0.192
# Step: 4141,bptt train Loss: 0.193
# Step: 4161,bptt train Loss: 0.251
# Step: 4181,bptt train Loss: 0.242
# Step: 4201,bptt train Loss: 0.243
# Step: 4221,bptt train Loss: 0.220
# Step: 4241,bptt train Loss: 0.286
# Step: 4261,bptt train Loss: 0.227
# Step: 4281,bptt train Loss: 0.115
# Step: 4301,bptt train Loss: 0.293
# Step: 4321,bptt train Loss: 0.259
# Step: 4341,bptt train Loss: 0.213
# Step: 4361,bptt train Loss: 0.451
# Step: 4381,bptt train Loss: 0.145
# Step: 4401,bptt train Loss: 0.270
# Step: 4421,bptt train Loss: 0.174
# Step: 4441,bptt train Loss: 0.203
# Step: 4461,bptt train Loss: 0.171
# Step: 4481,bptt train Loss: 0.195
# Step: 4501,bptt train Loss: 0.090
# Step: 4521,bptt train Loss: 0.205
# Step: 4541,bptt train Loss: 0.205
# Step: 4561,bptt train Loss: 0.263
# Step: 4581,bptt train Loss: 0.182
# Step: 4601,bptt train Loss: 0.248
# Step: 4621,bptt train Loss: 0.165
# Step: 4641,bptt train Loss: 0.129
# Step: 4661,bptt train Loss: 0.190
# Step: 4681,bptt train Loss: 0.267
# Step: 4701,bptt train Loss: 0.262
# Step: 4721,bptt train Loss: 0.191
# Step: 4741,bptt train Loss: 0.139
# Step: 4761,bptt train Loss: 0.249
# Step: 4781,bptt train Loss: 0.220
# Step: 4801,bptt train Loss: 0.309
# Step: 4821,bptt train Loss: 0.286
# Step: 4841,bptt train Loss: 0.213
# Step: 4861,bptt train Loss: 0.277
# Step: 4881,bptt train Loss: 0.236
# Step: 4901,bptt train Loss: 0.342
# Step: 4921,bptt train Loss: 0.258
# Step: 4941,bptt train Loss: 0.256
# Step: 4961,bptt train Loss: 0.290
# Step: 4981,bptt train Loss: 0.242
# Step: 5001,bptt train Loss: 0.317
# Optimization Finished!
# Model saved in path: /home/eghbal/MyData/KeRNL/logs/kernl_rnn_addition/add_eta_tensor_1e-08_eta_weight_1e-06_batch_2e+01_hum_hidd_1e+02_gc_1e+02_steps_5e+03_run_20190224_1657/model.ckpt-5000
